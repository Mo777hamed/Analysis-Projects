# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# Read the Excel file into a pandas DataFrame
df = pd.read_excel('Hunger in Africa.xlsx')

# %%
# You can then plot a bar chart to visualize the data
df.plot(kind='bar', x='Country', stacked=True, figsize=(10, 6))
plt.title('Land Use Distribution')
plt.xlabel('Country')
plt.ylabel('Percentage')
plt.show()

# %%
# Load a world map using geopandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# Out:
# C:\Users\ZB G3 STUDIO\AppData\Local\Temp\ipykernel_12448\417564642.py:2: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
# Merge the world map with the land use data
merged = world.merge(data, how='left', left_on='name', right_on='Country')

# %%
# Plot the map with land use data
fig, ax = plt.subplots(1, 1)
merged.boundary.plot(ax=ax)
merged.plot(column='Tree cover', ax=ax, legend=True,
            legend_kwds={'label': "Tree cover (%)", 'orientation': "horizontal"})
plt.show()
