# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>IMPORT LIBRARIES NEEDED</b>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# Out:
# C:\Users\ZB G3 STUDIO\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>COLORING LISTS</b>
# </div>

# %%
colors = ["#89CFF0", "#FF69B4", "#FFD700", "#7B68EE", "#FF4500",
          "#9370DB", "#32CD32", "#8A2BE2", "#FF6347", "#20B2AA",
          "#FF69B4", "#00CED1", "#FF7F50", "#7FFF00", "#DA70D6"]

color = ['#2c7fb8', '#7fcdbb', '#edf8b1']

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>LOAD THE DATASET</b>
# </div>

# %%
df = pd.read_csv('supermarket_sales .csv')

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>SHOW A DATASET SAMPLE</b>
# </div>

# %%
df.sample(6)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 515  413-20-6708      C  Naypyitaw        Member  Female
# 366  122-61-9553      C  Naypyitaw        Normal  Female
# 895  699-88-1972      B   Mandalay        Normal    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 367  468-88-0009      A     Yangon        Member    Male
# 842  860-73-6466      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 515     Fashion accessories       51.47         1   2.5735   54.0435
# 366  Electronic accessories       51.32         9  23.0940  484.9740
# 895       Health and beauty       99.16         8  39.6640  832.9440
# 994  Electronic accessories       60.95         1   3.0475   63.9975
# 367      Home and lifestyle       65.94         4  13.1880  276.9480
# 842       Sports and travel       39.47         2   3.9470   82.8870
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# ...

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>CHECK DATASET STRUCTURE</b>
# </div>

# %%
print(f'Records: {df.shape[0]}')
print(f'Columns: {df.shape[1]}')
# Out:
# Records: 1000
# Columns: 17

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>DATASET COLUMNS NAMES</b>
# </div>

# %%
column_names = df.keys().values.tolist()
column_names
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Unit price',
#  'Quantity',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'Payment',
#  'cogs',
#  'gross margin percentage',
#  'gross income',
#  'Rating']

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>COLUMNS DATA TYPES</b>
# </div>

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>CHECK FOR NULLS & MISSING VALUES</b>
# </div>

# %%
df.isnull()
# Out:
#      Invoice ID  Branch   City  Customer type  Gender  Product line  \
# 0         False   False  False          False   False         False
# 1         False   False  False          False   False         False
# 2         False   False  False          False   False         False
# 3         False   False  False          False   False         False
# 4         False   False  False          False   False         False
# ..          ...     ...    ...            ...     ...           ...
# 995       False   False  False          False   False         False
# 996       False   False  False          False   False         False
# 997       False   False  False          False   False         False
# 998       False   False  False          False   False         False
# 999       False   False  False          False   False         False
#
#      Unit price  Quantity  Tax 5%  Total   Date   Time  Payment   cogs  \
# 0         False     False   False  False  False  False    False  False
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>GENERAL INFORMATION ABOUT THE DATASET </b>
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>STATISTICAL SUMMARY OF THE DATASET</b>
# </div>

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>INVOICE ID DUPLICATE CHECK</b>
# </div>

# %%
df['Invoice ID'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Invoice ID, Length: 1000, dtype: bool

# %%
df['Invoice ID'].duplicated().value_counts()
# Out:
# Invoice ID
# False    1000
# Name: count, dtype: int64

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>INVOICE ID IS UNIQUE...
#                                 SET INVOICE ID AS INDEX </b>
# </div>

# %%
df.set_index('Invoice ID', inplace=True)

# %%
df.sample(3)
# Out:
#             Branch       City Customer type  Gender         Product line  \
# Invoice ID
# 379-17-6588      C  Naypyitaw        Normal    Male  Fashion accessories
# 848-24-9445      C  Naypyitaw        Member    Male    Health and beauty
# 241-96-5076      B   Mandalay        Member  Female   Home and lifestyle
#
#              Unit price  Quantity  Tax 5%    Total       Date   Time  \
# Invoice ID
# 379-17-6588       59.61        10  29.805  625.905  3/14/2019  11:07
# 848-24-9445       43.70         2   4.370   91.770  3/26/2019  18:03
# 241-96-5076       49.10         2   4.910  103.110   1/8/2019  12:58
#
#                  Payment   cogs  gross margin percentage  gross income  Rating
# Invoice ID
# 379-17-6588         Cash  596.1                 4.761905        29.805     5.3
# 848-24-9445         Cash   87.4                 4.761905         4.370     4.9
# 241-96-5076  Credit card   98.2                 4.761905         4.910     6.4

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>DATA ANALYSIS... </b>
# </div>

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>BRANCH</b>
# </div>

# %%
df['Branch'].value_counts()
# Out:
# Branch
# A    340
# B    332
# C    328
# Name: count, dtype: int64

# %%
plt.figure(figsize = (20, 6))

ax = df["Branch"].value_counts().plot(kind = 'bar', color = color, rot = 0)
ax.set_xticklabels(('A', 'B', 'C'))

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
    ax.tick_params(axis = 'both', labelsize = 15)
    
plt.xlabel('\nBranch', weight = "bold", color = "#D71313", fontsize = 20)
plt.ylabel('\nCustomers', weight = "bold", color = "#D71313", fontsize = 20)
# Out:
# Text(0, 0.5, '\nCustomers')

# %%
plt.figure(figsize = (20, 6))

counts = df["Branch"].value_counts()
explode = (0, 0.1, 0.1)

counts.plot(kind = 'pie', fontsize = 12, colors = color, explode = explode, autopct = '%.1f%%')
plt.title('Super Center Branches')
plt.xlabel('Branch', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.ylabel('Customers', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.legend(labels = counts.index, loc = 1)
plt.show()

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>CITY</b>
# </div>

# %%
df['City'].value_counts()
# Out:
# City
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: count, dtype: int64

# %%
plt.figure(figsize = (20, 6))

ax = df["City"].value_counts().plot(kind = 'bar', color = colors, rot = 0)
ax.set_xticklabels(('Yangon', 'Mandalay', 'Naypyitaw'))

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
    ax.tick_params(axis = 'both', labelsize = 15)
    
plt.xlabel('\nCity', weight = "bold", color = "#D71313", fontsize = 20)
plt.ylabel('\nCustomers', weight = "bold", color = "#D71313", fontsize = 20)
# Out:
# Text(0, 0.5, '\nCustomers')

# %%
plt.figure(figsize = (20, 6))

counts = df["City"].value_counts()
explode = (0, 0.1, 0.1)

counts.plot(kind = 'pie', fontsize = 12, colors = colors, explode = explode, autopct = '%.1f%%')

plt.xlabel('City', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.ylabel('', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.legend(labels = counts.index, loc = 'best')
plt.show()

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>CUSTOMER TYPE</b>
# </div>

# %%
df['Customer type'].value_counts()
# Out:
# Customer type
# Member    501
# Normal    499
# Name: count, dtype: int64

# %%
plt.figure(figsize = (20, 6))

ax = df["Customer type"].value_counts().plot(kind = 'bar', color = colors, rot = 0)
ax.set_xticklabels(('Member', 'Normal'))

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
    ax.tick_params(axis = 'both', labelsize = 15)
    
plt.xlabel('\nCustomer Type', weight = "bold", color = "#D71313", fontsize = 20)
plt.ylabel('\nCount', weight = "bold", color = "#D71313", fontsize = 20)
# Out:
# Text(0, 0.5, '\nCount')

# %%
plt.figure(figsize = (20, 6))

counts = df["Customer type"].value_counts()
explode = (0, 0)

counts.plot(kind = 'pie', fontsize = 12, colors = colors, explode = explode, autopct = '%.1f%%')

plt.xlabel('Customer Type', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.ylabel('', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.legend(labels = counts.index, loc = 'best')
plt.show()

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>CUSTOMERS GENDER</b>
# </div>

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    501
# Male      499
# Name: count, dtype: int64

# %%
plt.figure(figsize = (20, 6))

ax = df["Gender"].value_counts().plot(kind = 'bar', color = colors, rot = 0)
ax.set_xticklabels(('Female', 'Male'))

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
    ax.tick_params(axis = 'both', labelsize = 15)

plt.xlabel('Gender', weight = "bold", color = "#D71313", fontsize = 14)
plt.ylabel('Counts', weight = "bold", color = "#D71313", fontsize = 14)
# Out:
# Text(0, 0.5, 'Counts')

# %%
plt.figure(figsize = (20, 6))

counts = df["Gender"].value_counts()
explode = (0, 0.1)

counts.plot(kind = 'pie', fontsize = 12, colors = colors, explode = explode, autopct = '%.1f%%')
plt.title('Males Vs Females')
plt.xlabel('Gender', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.ylabel('Counts', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.legend(labels = counts.index, loc = "best")
plt.show()

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>PRODUCT LINE</b>
# </div>

# %%
df['Product line'].value_counts()
# Out:
# Product line
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: count, dtype: int64

# %%
plt.figure(figsize = (16, 6))

df['Product line'].value_counts().sort_values(ascending = False).plot(kind = 'bar', color = sns.color_palette('inferno'), edgecolor = 'black')
plt.xlabel('Product Line', weight = "bold", color = "#D71313", fontsize = 14, labelpad = 20)
plt.ylabel('\nFrequency', weight = "bold", color = "#D71313", fontsize = 14, labelpad = 20);
plt.xticks(rotation = 0, ha = 'center', fontsize = 16)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (30, 10))

counts = df["Product line"].value_counts()
explode = (0, 0, 0,0,0,0.2)

counts.plot(kind = 'pie', fontsize = 12, colors = colors, explode = explode, autopct = '%.1f%%')

plt.xlabel('City', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.ylabel('', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.legend(labels = counts.index, loc = 'best')
plt.show()

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>DERIVED METRICS CALCULATION</b>
# </div>

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>REVENUE</b>
# </div>

# %%
df['Revenue'] = df['Unit price'] * df['Quantity']
Revenue = df.groupby('Product line')['Revenue'].sum()

# %%
Revenue
# Out:
# Product line
# Electronic accessories    51750.03
# Fashion accessories       51719.90
# Food and beverages        53471.28
# Health and beauty         46851.18
# Home and lifestyle        51297.06
# Sports and travel         52497.93
# Name: Revenue, dtype: float64

# %%
plt.figure(figsize = (16, 6))

plt.bar(Revenue.index, Revenue.values, color = colors)

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
    ax.tick_params(axis = 'both', labelsize = 15)

plt.xlabel('\nProduct Line', weight = "bold", color = "#2F0F5D", fontsize = 14)
plt.ylabel('Revenue',  weight = "bold", color = "#2F0F5D", fontsize = 14)
plt.title('Revenue by Product Line')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>AVERAGE UNIT PRICE</b>
# </div>

# %%
average_unit_price = df.groupby('Product line')['Unit price'].mean()

# %%
average_unit_price
# Out:
# Product line
# Electronic accessories    53.551588
# Fashion accessories       57.153652
# Food and beverages        56.008851
# Health and beauty         54.854474
# Home and lifestyle        55.316937
# Sports and travel         56.993253
# Name: Unit price, dtype: float64

# %%
plt.hist(df['Unit price'], bins=10, color = colors[0])
plt.xlabel('Unit Price')
plt.ylabel('Frequency')
plt.title('Distribution of Unit Prices')
plt.show()

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>TOTAL QUANTITY</b>
# </div>

# %%
total_quantity = df.groupby('Product line')['Quantity'].sum()

# %%
total_quantity
# Out:
# Product line
# Electronic accessories    971
# Fashion accessories       902
# Food and beverages        952
# Health and beauty         854
# Home and lifestyle        911
# Sports and travel         920
# Name: Quantity, dtype: int64

# %%
plt.scatter(df['Quantity'], df['Unit price'], color = color[0])
plt.xlabel('Quantity')
plt.ylabel('Unit Price')
plt.title('Quantity vs Unit Price')
plt.show()

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>SALES GROWTH RATE</b>
# </div>

# %%
df.sort_values('Date', inplace=True)
df['revenue_prev_period'] = df.groupby('Product line')['Revenue'].shift(1)
df['growth_rate'] = (df['Revenue'] - df['revenue_prev_period']) / df['revenue_prev_period'] * 100

# %%
growth_rate = df.groupby('Product line')['growth_rate'].mean()
print(growth_rate)
# Out:
# Product line
# Electronic accessories    122.642216
# Fashion accessories       208.522823
# Food and beverages        100.387855
# Health and beauty         131.671686
# Home and lifestyle        123.335097
# Sports and travel         147.502858
# Name: growth_rate, dtype: float64

# %%
df['Date'] = pd.to_datetime(df['Date'])
sales_over_time = df.groupby(['Date', 'Product line'])['Revenue'].sum().unstack()

sales_over_time.plot(kind='line', marker='o', figsize=(18, 6))
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Sales Trend over Time')
plt.legend(title='Product Line', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>PAYMENT METHODS</b>
# </div>

# %%
df['Payment'].value_counts()
# Out:
# Payment
# Ewallet        345
# Cash           344
# Credit card    311
# Name: count, dtype: int64

# %%
plt.figure(figsize = (16, 6))

df["Payment"].value_counts().sort_values(ascending = False).plot(kind = 'bar', color = sns.color_palette('inferno'), edgecolor = 'black')
plt.xlabel('Payment Method', weight = "bold", color = "#D71313", fontsize = 14, labelpad = 20)
plt.ylabel('\nFrequency', weight = "bold", color = "#D71313", fontsize = 14, labelpad = 20);
plt.xticks(rotation = 0, ha = 'center', fontsize = 16)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (20, 6))

counts = df["Payment"].value_counts()
explode = (0, 0.1,  0.1)

counts.plot(kind = 'pie', fontsize = 12, colors = colors, explode = explode, autopct = '%.1f%%')
plt.xlabel('Payment Method', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.ylabel('Demonstration', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.axis('equal')
plt.legend(labels = counts.index, loc = "best")
plt.show()

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>GROSS MARGIN PROFIT</b>
# </div>

# %%
df['Date'] = pd.to_datetime(df['Date'])
gross_margin_percentage_over_time = df.groupby('Date')['gross margin percentage'].mean()

# %%
gross_margin_percentage_over_time
# Out:
# Date
# 2019-01-01    4.761905
# 2019-01-02    4.761905
# 2019-01-03    4.761905
# 2019-01-04    4.761905
# 2019-01-05    4.761905
#                 ...
# 2019-03-26    4.761905
# 2019-03-27    4.761905
# 2019-03-28    4.761905
# 2019-03-29    4.761905
# 2019-03-30    4.761905
# Name: gross margin percentage, Length: 89, dtype: float64

# %%
plt.plot(gross_margin_percentage_over_time.index, gross_margin_percentage_over_time.values)
plt.xlabel('Date')
plt.ylabel('Gross Margin Percentage')
plt.title('Gross Margin Percentage Trend over Time')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>COST OVER TIME</b>
# </div>

# %%
cogs_over_time = df.groupby('Date')['cogs'].sum()
gross_income_over_time = df.groupby('Date')['gross income'].sum()

# %%
gross_income_over_time
# Out:
# Date
# 2019-01-01    225.9610
# 2019-01-02     92.6430
# 2019-01-03     98.9585
# 2019-01-04     77.3185
# 2019-01-05    168.4135
#                 ...
# 2019-03-26     93.4530
# 2019-03-27    138.2295
# 2019-03-28    106.1620
# 2019-03-29    191.5830
# 2019-03-30    213.6695
# Name: gross income, Length: 89, dtype: float64

# %%
plt.plot(cogs_over_time.index, cogs_over_time.values, label='COGS')
plt.plot(gross_income_over_time.index, gross_income_over_time.values, label='Gross Income')

plt.xlabel('Date')
plt.ylabel('Amount')
plt.title('COGS and Gross Income Trend over Time')

plt.xticks(rotation=90)
plt.legend()

plt.show()

# %% [markdown]
# <div style="padding:10px;
#             color:#a9aba9;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:25px;
#             border-style: solid;
#             border-color: #141E46;
#             background-color:#141E46;
#             overflow:hidden;
#             font-weight:400"><b>RATING</b>
# </div>

# %%
mean = df['Rating'].mean()
print(f'The average rating is: {mean}')
# Out:
# The average rating is: 6.972700000000001

# %%
min = df['Rating'].min()
print(f'The minimum rating is: {min}')
# Out:
# The minimum rating is: 4.0

# %%
max = df['Rating'].max()
print(f'The maximum rating is: {max}')
# Out:
# The maximum rating is: 10.0

# %%
df['Date'] = pd.to_datetime(df['Date'])
rating_over_time = df.groupby('Date')['Rating'].mean()

plt.plot(rating_over_time.index, rating_over_time.values)
plt.xlabel('Date')
plt.ylabel('Rating')
plt.title('Rating Trend over Time')
plt.xticks(rotation=90)
plt.show()
